# %% [markdown]
# # Algebra

# %% [markdown]
# **Instructor:** Caeli Griffin @cagriffin@ucsd.edu
# **TAs:** Lauren Harvey & Kathryn Chen
#
# [Brief summary of lesson]
#
# Lecture notes adapted from/ inspired by (if applicable)

# %% [markdown]
# ## 1 | FIRST SECTION

# %% [markdown]
# ### 1.1 FIRST SUBSECTION
